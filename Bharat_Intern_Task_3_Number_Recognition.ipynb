# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# %%
# Loading the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# Preprocessing the data
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
# Designing and training a neural network model
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2615 - accuracy: 0.9245
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1152 - accuracy: 0.9664
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0782 - accuracy: 0.9774
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0597 - accuracy: 0.9812
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0468 - accuracy: 0.9853

# %%
# Evaluating the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0812 - accuracy: 0.9763
# Test accuracy: 0.9763000011444092

# %%
# Making predictions
predictions = model.predict(x_test)
predicted_labels = [tf.argmax(prediction).numpy() for prediction in predictions]
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
# Visualization of  predictions
for i in range(10):
    plt.imshow(x_test[i], cmap='gray')
    plt.title(f"Predicted label: {predicted_labels[i]}")
    plt.show()
